# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Project"
# Out:
# plant_disease.h5  Plant_images	plant_model.json  plant_model_weights.h5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
# from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam # - Works
# from keras.optimizers import Adam # - Does not Work
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
# from keras.utils import to_categorical 
from tensorflow.keras.utils import to_categorical

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Project/Plant_images/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %%
#Converting Images to array 
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))  
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
dir = "/content/drive/My Drive/Project/Plant_images"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    300
# 1    300
# 2    300
# dtype: int64

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 85, 85, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 85, 85, 16)        4624
#
#  max_pooling2d_1 (MaxPooling  (None, 42, 42, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 28224)             0
#
#  dense (Dense)               (None, 8)                 225800
#
#  dense_1 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 231,347
# Trainable params: 231,347
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 30s 6s/step - loss: 1.0359 - accuracy: 0.3403 - val_loss: 0.8978 - val_accuracy: 0.4167
# Epoch 2/50
# 5/5 [==============================] - 31s 6s/step - loss: 0.8677 - accuracy: 0.5972 - val_loss: 0.7594 - val_accuracy: 0.8542
# Epoch 3/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.7258 - accuracy: 0.8681 - val_loss: 0.6176 - val_accuracy: 0.8611
# Epoch 4/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.6021 - accuracy: 0.8021 - val_loss: 0.5050 - val_accuracy: 0.9653
# Epoch 5/50
# 5/5 [==============================] - 28s 5s/step - loss: 0.4891 - accuracy: 0.9583 - val_loss: 0.4090 - val_accuracy: 0.9861
# Epoch 6/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.3972 - accuracy: 0.9549 - val_loss: 0.3227 - val_accuracy: 0.9722
# Epoch 7/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.3263 - accuracy: 0.9670 - val_loss: 0.2604 - val_accuracy: 0.9792
# Epoch 8/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.2679 - accuracy: 0.9601 - val_loss: 0.2128 - val_accuracy: 0.9861
# Epoch 9/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.2221 - accuracy: 0.9774 - val_loss: 0.1746 - val_accuracy: 0.9792
# Epoch 10/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.1895 - accuracy: 0.9635 - val_loss: 0.1564 - val_accuracy: 1.0000
# Epoch 11/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.1644 - accuracy: 0.9826 - val_loss: 0.1230 - val_accuracy: 0.9861
# Epoch 12/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.1416 - accuracy: 0.9792 - val_loss: 0.1122 - val_accuracy: 1.0000
# Epoch 13/50
# 5/5 [==============================] - 30s 6s/step - loss: 0.1211 - accuracy: 0.9844 - val_loss: 0.0915 - val_accuracy: 0.9931
# Epoch 14/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.1076 - accuracy: 0.9896 - val_loss: 0.0832 - val_accuracy: 1.0000
# Epoch 15/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0940 - accuracy: 0.9878 - val_loss: 0.0689 - val_accuracy: 1.0000
# Epoch 16/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0820 - accuracy: 0.9896 - val_loss: 0.0690 - val_accuracy: 1.0000
# Epoch 17/50
# 5/5 [==============================] - 28s 5s/step - loss: 0.0771 - accuracy: 0.9878 - val_loss: 0.0548 - val_accuracy: 1.0000
# Epoch 18/50
# 5/5 [==============================] - 31s 6s/step - loss: 0.0669 - accuracy: 0.9913 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 19/50
# 5/5 [==============================] - 30s 6s/step - loss: 0.0605 - accuracy: 0.9965 - val_loss: 0.0449 - val_accuracy: 1.0000
# Epoch 20/50
50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.0164 - accuracy: 0.9983 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 34s 6s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 30s 6s/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 30s 6s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000

# %%
model.save("/content/drive/My Drive/Project/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('/content/drive/My Drive/Project/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/My Drive/Project/plant_model_weights.h5')

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 3s 484ms/step - loss: 0.0219 - accuracy: 1.0000
# Test Accuracy: 100.0

# %%
y_pred = model.predict(x_test)

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F01BD1A8250>

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight
